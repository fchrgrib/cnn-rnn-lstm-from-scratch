# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.metrics import f1_score
from keras._tf_keras.keras.models import Sequential
from keras._tf_keras.keras.layers import Embedding, LSTM, Dense, Dropout, TextVectorization, Bidirectional
import pandas as pd
import tensorflow as tf
import random
import os

# %% [markdown]
# # LSTM #
# ### Load Data

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)


train_df = pd.read_csv('../data/train.csv', dtype={'text': str, 'label': str})
val_df = pd.read_csv('../data/valid.csv', dtype={'text': str, 'label': str})
test_df = pd.read_csv('../data/test.csv', dtype={'text': str, 'label': str})

train_texts = train_df['text'].astype(str).tolist()
train_labels = train_df['label'].astype(str).tolist()

val_texts = val_df['text'].astype(str).tolist()
val_labels = val_df['label'].astype(str).tolist()

test_texts = test_df['text'].astype(str).tolist()
test_labels = test_df['label'].astype(str).tolist()

# Clean texts if theres any NaN or empty strings
train_texts = [text if text and not pd.isna(text) else "" for text in train_texts]
val_texts = [text if text and not pd.isna(text) else "" for text in val_texts]
test_texts = [text if text and not pd.isna(text) else "" for text in test_texts]

vocab_size = 10000
sequence_length = 100
embedding_dim = 100

# Create label map (ensure all labels are accounted for)
unique_labels = set(train_labels + val_labels + test_labels)
label_map = {label: idx for idx, label in enumerate(sorted(unique_labels))}

y_train = np.array([label_map[label] for label in train_labels])
y_val = np.array([label_map[label] for label in val_labels])
y_test = np.array([label_map[label] for label in test_labels])

vectorizer = TextVectorization(
    max_tokens=vocab_size,
    output_mode='int',
    output_sequence_length=sequence_length,
    standardize='lower_and_strip_punctuation'
)

vectorizer.adapt(np.array(train_texts))

# %% [markdown]
# ### Experiment
# #### Number of Layers

# %%
epochs = 10
batch_size = 32

lay = {
    "1 LSTM": [
        vectorizer,
        Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  mask_zero=True,
                  embeddings_initializer='uniform'),
        LSTM(64),
        Dropout(0.5, seed=SEED),
        Dense(len(label_map),
              activation='softmax')
    ],
    "3 LSTM": [
        vectorizer,
        Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  mask_zero=True,
                  embeddings_initializer='uniform'),
        LSTM(64, return_sequences=True),
        LSTM(64, return_sequences=True),
        LSTM(64),
        Dropout(0.5, seed=SEED),
        Dense(len(label_map),
              activation='softmax')
    ],
    "6 LSTM": [
        vectorizer,
        Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  mask_zero=True,
                  embeddings_initializer='uniform'),
        LSTM(64, return_sequences=True),
        LSTM(64, return_sequences=True),
        LSTM(64, return_sequences=True),
        LSTM(64, return_sequences=True),
        LSTM(64, return_sequences=True),
        LSTM(64),
        Dropout(0.5, seed=SEED),
        Dense(len(label_map),
              activation='softmax')
    ]
}


accuracy = []
train_loss = {}
val_loss = {}
f1_scores = []

for name, layers in lay.items():
    
    tf.random.set_seed(SEED)
    np.random.seed(SEED)
    
    model = Sequential(layers)
    
    model.compile(
        loss="sparse_categorical_crossentropy", 
        optimizer='adam',
        metrics=["accuracy"]
    )
    
    history = model.fit(
        np.array(train_texts, dtype=object),
        y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(np.array(val_texts, dtype=object), y_val),
        verbose=1,
        shuffle=True
    )
    
    train_loss[name] = history.history["loss"]
    val_loss[name] = history.history["val_loss"]
    
    score = model.evaluate(np.array(test_texts, dtype=object), y_test, verbose=0)
    accuracy.append(score[1])
    
    y_pred = model.predict(np.array(test_texts, dtype=object), verbose=0)
    y_pred_classes = y_pred.argmax(axis=1)
    f1 = f1_score(y_test.flatten(), y_pred_classes, average='macro')
    f1_scores.append(f1)

# Plot training loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
for name, tl in train_loss.items():
    plt.plot(tl, label=name)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()
plt.grid(True)

# Plot validation loss
plt.subplot(1, 2, 2)
for name, vl in val_loss.items():
    plt.plot(vl, label=name)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot accuracy comparison
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
names = list(lay.keys())
plt.bar(names, accuracy)
plt.title("Test Accuracy vs Number of Layers")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)

# Plot F1 score comparison
plt.subplot(1, 2, 2)
plt.bar(names, f1_scores)
plt.title("Macro F1 Score vs Number of Layers")
plt.ylabel("Macro F1 Score")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

for name, acc, f1 in zip(names, accuracy, f1_scores):
    print(f"{name}:")
    print(f"  Accuracy: {acc:.4f}")
    print(f"  F1 Score: {f1:.4f}")
# Out:
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.4474 - loss: 1.0880 - val_accuracy: 0.5400 - val_loss: 1.0468
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5172 - loss: 0.9737 - val_accuracy: 0.6600 - val_loss: 0.9429
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7885 - loss: 0.7792 - val_accuracy: 0.6800 - val_loss: 0.7692
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9215 - loss: 0.4133 - val_accuracy: 0.7600 - val_loss: 0.7567
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9489 - loss: 0.2497 - val_accuracy: 0.7700 - val_loss: 0.7351
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9888 - loss: 0.1340 - val_accuracy: 0.7500 - val_loss: 0.6897
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9946 - loss: 0.0913 - val_accuracy: 0.7600 - val_loss: 0.7326
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9964 - loss: 0.0469 - val_accuracy: 0.7900 - val_loss: 0.7709
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9964 - loss: 0.0332 - val_accuracy: 0.7600 - val_loss: 0.8605
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9964 - loss: 0.0200 - val_accuracy: 0.7600 - val_loss: 0.9133
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.3631 - loss: 1.0746 - val_accuracy: 0.3900 - val_loss: 1.0012
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.5326 - loss: 0.9050 - val_accuracy: 0.6100 - val_loss: 0.8899
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.7182 - loss: 0.6309 - val_accuracy: 0.6000 - val_loss: 0.8888
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8868 - loss: 0.3467 - val_accuracy: 0.6900 - val_loss: 1.1036
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9617 - loss: 0.1424 - val_accuracy: 0.6700 - val_loss: 1.3525
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9710 - loss: 0.1392 - val_accuracy: 0.7000 - val_loss: 1.2625
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9874 - loss: 0.0641 - val_accuracy: 0.7200 - val_loss: 1.2327
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9862 - loss: 0.0603 - val_accuracy: 0.7100 - val_loss: 1.1889
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9891 - loss: 0.0496 - val_accuracy: 0.7200 - val_loss: 1.2685
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9915 - loss: 0.0582 - val_accuracy: 0.7200 - val_loss: 1.2557
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 0.3659 - loss: 1.0630 - val_accuracy: 0.4400 - val_loss: 0.9997
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.5177 - loss: 0.9329 - val_accuracy: 0.5700 - val_loss: 0.8964
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.6324 - loss: 0.7651 - val_accuracy: 0.5500 - val_loss: 0.9415
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.7747 - loss: 0.5518 - val_accuracy: 0.6000 - val_loss: 1.0401
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.8425 - loss: 0.4447 - val_accuracy: 0.6300 - val_loss: 1.0713
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - accuracy: 0.8916 - loss: 0.3431 - val_accuracy: 0.6100 - val_loss: 1.1486
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - accuracy: 0.8994 - loss: 0.2767 - val_accuracy: 0.5600 - val_loss: 1.3300
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - accuracy: 0.9208 - loss: 0.2759 - val_accuracy: 0.4900 - val_loss: 1.6075
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.8949 - loss: 0.3268 - val_accuracy: 0.5600 - val_loss: 1.3319
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.9074 - loss: 0.3133 - val_accuracy: 0.6300 - val_loss: 1.1880
# 1 LSTM:
#   Accuracy: 0.7450
#   F1 Score: 0.7367
# 3 LSTM:
#   Accuracy: 0.7300
#   F1 Score: 0.7229
# 6 LSTM:
#   Accuracy: 0.6150
#   F1 Score: 0.5698

# %% [markdown]
# ### Number of Cells

# %%
epochs = 10
batch_size = 32


cells = {
    "32 Cells": [
        vectorizer,
        Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  mask_zero=True,
                  embeddings_initializer='uniform'),
        LSTM(32),
        Dropout(0.5, seed=SEED),
        Dense(len(label_map),
              activation='softmax')
    ],
    "64 Cells": [
        vectorizer,
        Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  mask_zero=True,
                  embeddings_initializer='uniform'),
        LSTM(64),
        Dropout(0.5, seed=SEED),
        Dense(len(label_map),
              activation='softmax')
    ],
    "128 Cells": [
        vectorizer,
        Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  mask_zero=True,
                  embeddings_initializer='uniform'),
        LSTM(128),
        Dropout(0.5, seed=SEED),
        Dense(len(label_map),
              activation='softmax')
    ]
}


accuracy = []
train_loss = {}
val_loss = {}
f1_scores = []

for name, layers in cells.items():
    
    tf.random.set_seed(SEED)
    np.random.seed(SEED)
    
    model = Sequential(layers)
    
    model.compile(
        loss="sparse_categorical_crossentropy", 
        optimizer='adam',
        metrics=["accuracy"]
    )
    
    history = model.fit(
        np.array(train_texts, dtype=object),
        y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(np.array(val_texts, dtype=object), y_val),
        verbose=1,
        shuffle=True
    )
    
    train_loss[name] = history.history["loss"]
    val_loss[name] = history.history["val_loss"]
    
    score = model.evaluate(np.array(test_texts, dtype=object), y_test, verbose=0)
    accuracy.append(score[1])
    
    y_pred = model.predict(np.array(test_texts, dtype=object), verbose=0)
    y_pred_classes = y_pred.argmax(axis=1)
    f1 = f1_score(y_test.flatten(), y_pred_classes, average='macro')
    f1_scores.append(f1)

# Plot training loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
for name, tl in train_loss.items():
    plt.plot(tl, label=name)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()
plt.grid(True)

# Plot validation loss
plt.subplot(1, 2, 2)
for name, vl in val_loss.items():
    plt.plot(vl, label=name)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot accuracy comparison
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
names = list(cells.keys())
plt.bar(names, accuracy)
plt.title("Test Accuracy vs Number of Cells")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)

# Plot F1 score comparison
plt.subplot(1, 2, 2)
plt.bar(names, f1_scores)
plt.title("Macro F1 Score vs Number of Cells")
plt.ylabel("Macro F1 Score")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

for name, acc, f1 in zip(names, accuracy, f1_scores):
    print(f"{name}:")
    print(f"  Accuracy: {acc:.4f}")
    print(f"  F1 Score: {f1:.4f}")
# Out:
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.3886 - loss: 1.0913 - val_accuracy: 0.6000 - val_loss: 1.0597
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5785 - loss: 1.0150 - val_accuracy: 0.6300 - val_loss: 0.9620
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6518 - loss: 0.7967 - val_accuracy: 0.6900 - val_loss: 0.7972
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8708 - loss: 0.4690 - val_accuracy: 0.7800 - val_loss: 0.6979
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9573 - loss: 0.3314 - val_accuracy: 0.8100 - val_loss: 0.6689
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9892 - loss: 0.2052 - val_accuracy: 0.8100 - val_loss: 0.6881
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9929 - loss: 0.1416 - val_accuracy: 0.8100 - val_loss: 0.6122
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9939 - loss: 0.0979 - val_accuracy: 0.8000 - val_loss: 0.7326
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9939 - loss: 0.0750 - val_accuracy: 0.8000 - val_loss: 0.7350
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9933 - loss: 0.0590 - val_accuracy: 0.7600 - val_loss: 0.7373
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.4274 - loss: 1.0905 - val_accuracy: 0.4000 - val_loss: 1.0637
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5234 - loss: 1.0041 - val_accuracy: 0.5000 - val_loss: 0.9476
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7255 - loss: 0.7923 - val_accuracy: 0.6900 - val_loss: 0.7785
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8548 - loss: 0.5220 - val_accuracy: 0.7700 - val_loss: 0.7118
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9594 - loss: 0.3250 - val_accuracy: 0.7500 - val_loss: 0.6690
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9836 - loss: 0.1817 - val_accuracy: 0.7500 - val_loss: 0.6849
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9927 - loss: 0.0897 - val_accuracy: 0.7600 - val_loss: 0.7806
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9927 - loss: 0.0515 - val_accuracy: 0.7500 - val_loss: 0.8785
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9964 - loss: 0.0370 - val_accuracy: 0.7500 - val_loss: 0.9013
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0278 - val_accuracy: 0.7500 - val_loss: 0.9587
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.4220 - loss: 1.0874 - val_accuracy: 0.4000 - val_loss: 1.0129
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5551 - loss: 0.9383 - val_accuracy: 0.5700 - val_loss: 0.9059
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8479 - loss: 0.7006 - val_accuracy: 0.6900 - val_loss: 0.7411
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9370 - loss: 0.3514 - val_accuracy: 0.7100 - val_loss: 0.8134
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9456 - loss: 0.2703 - val_accuracy: 0.7000 - val_loss: 0.6916
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9919 - loss: 0.1347 - val_accuracy: 0.7100 - val_loss: 0.8180
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9873 - loss: 0.0670 - val_accuracy: 0.7200 - val_loss: 0.8854
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9990 - loss: 0.0302 - val_accuracy: 0.7400 - val_loss: 0.7950
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9963 - loss: 0.0392 - val_accuracy: 0.6900 - val_loss: 0.9111
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9996 - loss: 0.0119 - val_accuracy: 0.7300 - val_loss: 0.9484
# 32 Cells:
#   Accuracy: 0.7600
#   F1 Score: 0.7540
# 64 Cells:
#   Accuracy: 0.7325
#   F1 Score: 0.7240
# 128 Cells:
#   Accuracy: 0.7325
#   F1 Score: 0.7200

# %% [markdown]
# ### Type of RNN

# %%
epochs = 10
batch_size = 32

rnn_types = {
    "LSTM": [
        vectorizer,
        Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  mask_zero=True,
                  embeddings_initializer='uniform'),
        LSTM(64),
        Dropout(0.5, seed=SEED),
        Dense(len(label_map), 
              activation='softmax')
    ],
    "Bidirectional LSTM": [
        vectorizer,
        Embedding(input_dim=vocab_size + 1,
                  output_dim=embedding_dim,
                  mask_zero=True,
                  embeddings_initializer='uniform'),
        Bidirectional(LSTM(64)),
        Dropout(0.5, seed=SEED),
        Dense(len(label_map), 
              activation='softmax')
    ]
}

accuracy = []
train_loss = {}
val_loss = {}
f1_scores = []

for name, layers in rnn_types.items():
    tf.random.set_seed(SEED)
    np.random.seed(SEED)
    
    model = Sequential(layers)
    
    model.compile(
        loss="sparse_categorical_crossentropy", 
        optimizer='adam',
        metrics=["accuracy"]
    )
    
    history = model.fit(
        np.array(train_texts, dtype=object),
        y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(np.array(val_texts, dtype=object), y_val),
        verbose=1,
        shuffle=True
    )
    
    train_loss[name] = history.history["loss"]
    val_loss[name] = history.history["val_loss"]
    
    score = model.evaluate(np.array(test_texts, dtype=object), y_test, verbose=0)
    accuracy.append(score[1])
    
    y_pred = model.predict(np.array(test_texts, dtype=object), verbose=0)
    y_pred_classes = y_pred.argmax(axis=1)
    f1 = f1_score(y_test.flatten(), y_pred_classes, average='macro')
    f1_scores.append(f1)
    
# Plot training loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
for name, tl in train_loss.items():
    plt.plot(tl, label=name)
    
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()
plt.grid(True)

# Plot validation loss
plt.subplot(1, 2, 2)
for name, vl in val_loss.items():
    plt.plot(vl, label=name)
    
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot accuracy comparison
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
names = list(rnn_types.keys())
plt.bar(names, accuracy)
plt.title("Test Accuracy vs Type of RNN")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)

# Plot F1 score comparison
plt.subplot(1, 2, 2)
plt.bar(names, f1_scores)
plt.title("Macro F1 Score vs Type of RNN")
plt.ylabel("Macro F1 Score")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

for name, acc, f1 in zip(names, accuracy, f1_scores):
    print(f"{name}:")
    print(f"  Accuracy: {acc:.4f}")
    print(f"  F1 Score: {f1:.4f}")
# Out:
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.3989 - loss: 1.0890 - val_accuracy: 0.4200 - val_loss: 1.0438
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5476 - loss: 0.9672 - val_accuracy: 0.6300 - val_loss: 0.9455
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7879 - loss: 0.7584 - val_accuracy: 0.6900 - val_loss: 0.8122
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9248 - loss: 0.3711 - val_accuracy: 0.7600 - val_loss: 0.8083
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9602 - loss: 0.2121 - val_accuracy: 0.7500 - val_loss: 0.7221
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9933 - loss: 0.0996 - val_accuracy: 0.7500 - val_loss: 0.8194
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9961 - loss: 0.0512 - val_accuracy: 0.7600 - val_loss: 0.9001
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9925 - loss: 0.0401 - val_accuracy: 0.7200 - val_loss: 1.0322
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9939 - loss: 0.0327 - val_accuracy: 0.7700 - val_loss: 0.8892
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.7600 - val_loss: 0.9631
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.4596 - loss: 1.0863 - val_accuracy: 0.4800 - val_loss: 1.0358
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5619 - loss: 0.9474 - val_accuracy: 0.6600 - val_loss: 0.9253
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7929 - loss: 0.7112 - val_accuracy: 0.6700 - val_loss: 0.8029
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9165 - loss: 0.3660 - val_accuracy: 0.7800 - val_loss: 0.7721
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9647 - loss: 0.2234 - val_accuracy: 0.8000 - val_loss: 0.7051
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9902 - loss: 0.1033 - val_accuracy: 0.8000 - val_loss: 0.6620
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9927 - loss: 0.0537 - val_accuracy: 0.7800 - val_loss: 0.7057
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9920 - loss: 0.0356 - val_accuracy: 0.8100 - val_loss: 0.6645
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9948 - loss: 0.0250 - val_accuracy: 0.7900 - val_loss: 0.6974
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.8100 - val_loss: 0.7207
# LSTM:
#   Accuracy: 0.7500
#   F1 Score: 0.7425
# Bidirectional LSTM:
#   Accuracy: 0.7500
#   F1 Score: 0.7399
